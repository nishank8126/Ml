# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('tc dataset.csv')
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
col1="petal_width"
col2="sepal_length"
selected_data=df[[col1,col2]]

# %%
plt.figure(figsize=(8,5))
plt.scatter(selected_data[col1],selected_data[col2],color='blue',alpha=0.8)
plt.title(f' scatter plot of {col1} vs {col2}')
plt.xlabel(col1)
plt.ylabel(col2)
plt.grid(True)
plt.show()

# %%
cor_coef=np.corrcoef(selected_data[col1],selected_data[col2])[0,1]
print(f'pearson correlation coefficient ({col1} vs {col2}): {cor_coef}')
# Out:
# pearson correlation coefficient (petal_width vs sepal_length): 0.8179536333691634

# %%
cov_matrix=np.cov(selected_data[col1],selected_data[col2])
print("covariance matrix:")
print(cov_matrix)
# Out:
# covariance matrix:
# [[0.58241432 0.5169038 ]
#  [0.5169038  0.68569351]]

# %%
correlation_matrix = selected_data.corr()
print("\ncorrelation matrix:")
print(correlation_matrix)
# Out:
# correlation matrix:
#               petal_width  sepal_length
# petal_width      1.000000      0.817954
# sepal_length     0.817954      1.000000

# %%
plt.figure(figsize=(8,5))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)
plt.title("heatmap")
plt.show()

# %%
col3="petal_width"
col4="sepal_length"
selected_data=df[[col3,col4]]

# %%
plt.figure(figsize=(8,5))
plt.scatter(selected_data[col3],selected_data[col4],color='blue',alpha=0.8)
plt.title(f' scatter plot of {col3} vs {col4}')
plt.xlabel(col3)
plt.ylabel(col4)
plt.grid(True)
plt.show()

# %%
cor_coef=np.corrcoef(selected_data[col3],selected_data[col4])[0,1]
print(f'pearson correlation coefficient ({col3} vs {col4}): {cor_coef}')
# Out:
# pearson correlation coefficient (petal_width vs sepal_length): 0.8179536333691634

# %%
cov_matrix=np.cov(selected_data[col3],selected_data[col4])
print("covariance matrix:")
print(cov_matrix)
# Out:
# covariance matrix:
# [[0.58241432 0.5169038 ]
#  [0.5169038  0.68569351]]

# %%
correlation_matrix = selected_data.corr()
print("\ncorrelation matrix:")
print(correlation_matrix)
# Out:
# correlation matrix:
#               petal_width  sepal_length
# petal_width      1.000000      0.817954
# sepal_length     0.817954      1.000000

# %%
plt.figure(figsize=(8,5))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)
plt.title("heatmap")
plt.show()
